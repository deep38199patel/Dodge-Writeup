# %% [markdown]
# <a href="https://colab.research.google.com/github/deep38199patel/Dodge-Writeup/blob/deep38199patel-patch-1/Fraud_Detection_in_Multi_Factor_Authentication_(MFA)_Using_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 208030  136944.0 -2.296779  0.160723  0.029033  0.924372 -0.837166  0.988358
# 208031  136944.0 -0.813941  0.706229  0.291162 -2.623354  0.563792 -0.190741
# 208032  136944.0 -0.660347  1.147467  0.046288 -0.913694  0.741224 -1.325788
# 208033  136944.0  0.084981  0.948412 -0.343832 -0.619860  0.854294 -0.587994
# 208034  136944.0 -1.580655 -0.407163  0.677965  1.328521  1.549646 -0.563803
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 208030  0.111401  1.173111 -0.304353  ...  0.295344  0.746659  0.155402
# 208031 -0.064674 -3.175029 -1.521131  ... -1.171450  0.618023 -0.012904
# 208032  1.299686 -0.297240  0.044566  ...  0.291957  0.765911 -0.373310
# 208033  0.871052  0.046588 -0.262800  ... -0.282280 -0.728923  0.117186
# 208034  0.342159  0.186344 -0.731562  ...       NaN       NaN       NaN
#
# ...

# %%
# first 5 row of the dataset
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 208030  136944.0 -2.296779  0.160723  0.029033  0.924372 -0.837166  0.988358
# 208031  136944.0 -0.813941  0.706229  0.291162 -2.623354  0.563792 -0.190741
# 208032  136944.0 -0.660347  1.147467  0.046288 -0.913694  0.741224 -1.325788
# 208033  136944.0  0.084981  0.948412 -0.343832 -0.619860  0.854294 -0.587994
# 208034  136944.0 -1.580655 -0.407163  0.677965  1.328521  1.549646 -0.563803
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 208030  0.111401  1.173111 -0.304353  ...  0.295344  0.746659  0.155402
# 208031 -0.064674 -3.175029 -1.521131  ... -1.171450  0.618023 -0.012904
# 208032  1.299686 -0.297240  0.044566  ...  0.291957  0.765911 -0.373310
# 208033  0.871052  0.046588 -0.262800  ... -0.282280 -0.728923  0.117186
# 208034  0.342159  0.186344 -0.731562  ...       NaN       NaN       NaN
#
# ...

# %%
#dataset info
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208035 entries, 0 to 208034
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    208035 non-null  float64
#  1   V1      208035 non-null  float64
#  2   V2      208035 non-null  float64
#  3   V3      208035 non-null  float64
#  4   V4      208035 non-null  float64
#  5   V5      208035 non-null  float64
#  6   V6      208035 non-null  float64
#  7   V7      208035 non-null  float64
#  8   V8      208035 non-null  float64
#  9   V9      208035 non-null  float64
#  10  V10     208035 non-null  float64
#  11  V11     208035 non-null  float64
#  12  V12     208035 non-null  float64
#  13  V13     208035 non-null  float64
#  14  V14     208035 non-null  float64
#  15  V15     208034 non-null  float64
#  16  V16     208034 non-null  float64
#  17  V17     208034 non-null  float64
#  18  V18     208034 non-null  float64
#  19  V19     208034 non-null  float64
# ...

# %%
# checking number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraud transcations
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    207641
# 1.0       393
# Name: count, dtype: int64

# %% [markdown]
# this dataset is high unbalanced
#
# 0- normal transaction
# 1= fraud transaction

# %%
from operator import length_hint
#separte the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print (legit.shape)
print(fraud.shape)
# Out:
# (207641, 31)
# (393, 31)

# %%
#statsically measure of the data
legit.Amount.describe()
# Out:
# count    207641.000000
# mean         89.843752
# std         247.988362
# min           0.000000
# 25%           6.000000
# 50%          23.030000
# 75%          79.540000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     393.000000
# mean      123.386005
# std       257.134306
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    73151.716145 -0.078618 -0.009427  0.290498  0.056231 -0.087794
# 1.0    62781.541985 -5.579849  4.152674 -7.660395  4.742284 -4.017895
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.043980 -0.029531  0.011218  0.012859  ...  0.015750 -0.013780
# 1.0   -1.396601 -6.509509  0.663476 -2.748126  ...  0.394684  0.778507
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.039185 -0.013908  0.003622  0.053625  0.004850  0.000656  0.001533
# 1.0   -0.012563 -0.048989 -0.065777  0.065806  0.038768  0.180565  0.059636
#
#            Amount
# Class
# 0.0     89.843752
# 1.0    123.386005
#
# [2 rows x 30 columns]

# %% [markdown]
# Under : Sampling data

# %% [markdown]
# Building a sample dataset similar of normal transaction and fraud transaction
#
# Number of fraud transaction

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concate the two dataframe

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 34430    37664.0 -0.026940 -0.001857  1.113535 -1.882898 -0.755429 -1.400800
# 154361  101274.0  2.005855 -0.171692 -0.325345  0.513632 -0.275777 -0.128326
# 24294    33161.0  1.528480 -1.101018  0.369775 -1.709021 -1.136988  0.205776
# 109278   71306.0 -0.161020 -0.247439  1.697323 -1.938570 -1.338907 -0.683638
# 182123  125266.0 -0.851297  0.666682  0.568273  0.686134  1.129951  2.479856
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 34430   0.292494 -0.415592 -2.952864  ... -0.060738  0.233894 -0.185570
# 154361 -0.611888 -0.049457  2.534901  ... -0.339676 -0.591833  0.412944
# 24294  -1.306216  0.021943 -1.925653  ... -0.070984  0.217588 -0.173811
# 109278 -0.218625 -0.223420 -2.402497  ... -0.274889 -0.453063  0.066682
# 182123 -0.056372  0.903296  0.154550  ... -0.329158 -0.640195  0.311518
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 203328  134769.0 -0.967767  2.098019 -5.222929  6.514573 -4.187674  2.114178
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204503  135314.0 -3.158990  1.765452 -3.390168  0.987410 -1.509930 -1.280952
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 203328  0.948701 -2.448427 -3.203666  ... -0.843268  0.796739  1.314312
# 203700 -0.781880  0.076619 -2.976249  ...  0.098341 -0.845866 -0.031228
# 204064 -1.020407  0.547069 -1.105990  ...  0.911373  1.042929  0.999394
# 204079  0.298621 -0.282416  0.802053  ... -0.204158 -0.511441  0.077874
# 204503 -2.719557  0.718325 -1.660183  ...  1.120533  1.605085 -0.618637
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    393
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    72169.754065 -0.072935  0.009643  0.264636 -0.006527 -0.165474
# 1.0    62781.541985 -5.579849  4.152674 -7.660395  4.742284 -4.017895
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.007535 -0.073794  0.122280 -0.079876  ...  0.006263  0.016912
# 1.0   -1.396601 -6.509509  0.663476 -2.748126  ...  0.394684  0.778507
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.011101 -0.018424  0.036854  0.072449  0.001329  0.014484  0.006008
# 1.0   -0.012563 -0.048989 -0.065777  0.065806  0.038768  0.180565  0.059636
#
#            Amount
# Class
# 0.0     86.880427
# 1.0    123.386005
#
# [2 rows x 30 columns]

# %% [markdown]
# Split the data in to feature & targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print (X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 34430    37664.0 -0.026940 -0.001857  1.113535 -1.882898 -0.755429 -1.400800
# 154361  101274.0  2.005855 -0.171692 -0.325345  0.513632 -0.275777 -0.128326
# 24294    33161.0  1.528480 -1.101018  0.369775 -1.709021 -1.136988  0.205776
# 109278   71306.0 -0.161020 -0.247439  1.697323 -1.938570 -1.338907 -0.683638
# 182123  125266.0 -0.851297  0.666682  0.568273  0.686134  1.129951  2.479856
# ...          ...       ...       ...       ...       ...       ...       ...
# 203328  134769.0 -0.967767  2.098019 -5.222929  6.514573 -4.187674  2.114178
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204503  135314.0 -3.158990  1.765452 -3.390168  0.987410 -1.509930 -1.280952
#
# ...

# %%
print (Y)
# Out:
# 34430     0.0
# 154361    0.0
# 24294     0.0
# 109278    0.0
# 182123    0.0
#          ...
# 203328    1.0
# 203700    1.0
# 204064    1.0
# 204079    1.0
# 204503    1.0
# Name: Class, Length: 885, dtype: float64

# %% [markdown]
# Split data in to trained data & testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print (X.shape, X_train.shape, X_test.shape)
# Out:
# (885, 30) (708, 30) (177, 30)

# %% [markdown]
# Model Training:
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training logistic regression model with training data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on training data:', training_data_accuracy )
# Out:
# Accuracy on training data: 0.9562146892655368

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on test data:', test_data_accuracy )
# Out:
# Accuracy on test data: 0.9265536723163842
